# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Fatima8211/ML_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane: Content Refresh / Declining Pages
#
# I want to investigate which content pages should be prioritized for review or refresh based on their search performance. I chose this lane because the starter data contains signals such as impressions, clicks, CTR, average position, content age, and recent performance trends. A useful result would help a content or SEO team decide which pages deserve attention first instead of reviewing pages manually or relying only on a simple rule. I will treat this as a provisional lane and use the data to see which signals are useful for making that prioritization decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The question: decision, action, cost of a wrong call
#
# The decision is which content pages should be prioritized for SEO or content review. An SEO or content team member would act on the recommendation by reviewing selected pages and deciding whether to update, improve, or leave them unchanged. A wrong recommendation could waste time and effort on a page that does not need attention, while missing a page that could benefit from a refresh could result in a missed opportunity to improve search performance. The goal is therefore to support prioritization, not to automatically decide which pages must be changed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Quick look at the data
#
# The starter dataset contains 30,000 pages. All 30,000 pages have recorded impressions, and 19,715 pages have a declining trend. The average page received about 5,200 impressions over 90 days, while the average search volume was about 159. These numbers suggest that there is enough search-performance data to investigate which pages may need attention and how their characteristics relate to declining performance.

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd

url = "https://raw.githubusercontent.com/Fatima8211/ML_Internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))
print("Pages with impressions > 0:", (df["impressions_90d"] > 0).sum())
print("Pages with declining trend:", (df["trend_pct"] < 0).sum())

print("\nAverage 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Average search volume:", round(df["search_volume"].mean(), 2))

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Number of rows: 30000
# Pages with impressions > 0: 30000
# Pages with declining trend: 19715
#
# Average 90-day impressions: 5200.37
# Average search volume: 158.88

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# Careful words: what I can and can't claim
#
# I can use the available data to observe patterns in search performance and identify pages that may be worth reviewing or refreshing. The results will be directional and intended for decision-support, helping an SEO or content team prioritize pages for further review. I cannot claim that the observed relationships are causal, that a content refresh will definitely improve performance, or that the analysis can predict how Google will rank a page. The analysis can support a decision, but it cannot replace human review or prove what caused a change in search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
